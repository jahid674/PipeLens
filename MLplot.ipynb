# %%
import matplotlib as plt
import pylab as plot
import matplotlib
import os
import numpy as np

# %% [markdown]
# ## Fairness

# %%
task='fairness'
case='worst_revision_NN'

# %% [markdown]
# #### Median

# %%
Grid_m=[2, 4, 6, 34]
#Grid_ES_m=[2, 3, 15, 45]
l2c_m=[19, 21, 37]
BugDoc_m=[44, 44, 46, 46]
PipeLens_m=[1, 1, 3, 18]

# %% [markdown]
# #### Worst

# %%
Grid_w=[8,26, 31, 373]
#Grid_ES_w=[8, 14, 103, 261]
l2c_w=[9, 19, 41]
BugDoc_w=[47,47,47, 64]
PipeLens_w=[8, 14, 18, 18]

# %% [markdown]
# #### Tight fgoal

# %%
Grid_t=[10, 34, 69, 373]
#Grid_ES_t=[22, 45, 84, 261]
l2c_t=[57]
BugDoc_t=[44,46,47,64]
PipeLens_t=[1,4,10,18]

# %% [markdown]
# #### Relaxed fgoal

# %%
Grid_r=[1,2,3,8]
#Grid_ES_r=[1,2,3,8]
l2c_r=[3,3,5,9]
BugDoc_r=[40,44,46,47]
PipeLens_r=[1,1,1,8]
#pipelens_o_r=[1,1,2,3]

# %%
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.pyplot as plot  # for plot.rcParams usage
import matplotlib.ticker as mticker
from matplotlib.ticker import LogLocator, LogFormatterMathtext, NullFormatter

fsize = 20
params = {'legend.fontsize': fsize, 'legend.handlelength': 2}
plot.rcParams.update(params)

font = {'family': "sans serif", 'size': fsize}
matplotlib.rc('font', **font)

# --- Save path ---
folder_path = '/Users/hasan89/Documents/PipeLens_Plot/practise/Fairness'
file_name = f"{task}_{case}.pdf"

os.makedirs(folder_path, exist_ok=True)
file_path = os.path.join(folder_path, file_name)

# ... your existing code above ...

plt.figure(figsize=(6, 5))
plt.xticks(fontsize=fsize/1.2)
plt.yticks(fontsize=fsize/1.2)

x_en = [0.84, 0.86, 0.88, 0.90]
#x_en = [25, 50, 75, 100]
# Map to evenly spaced positions
labels = [f"{v}" for v in x_en]
#labels = [f"{v:.2f}" for v in x_en]
#xpos = np.arange(len(x_en))  # 0,1,2,3 (equally spaced)
xpos = x_en
# Plot against xpos (not x_en)
plt.plot(xpos, Grid_m,     marker='o', linestyle='-', color='navy',       markersize=18, label='GridSearch-ES')
#plt.plot(xpos, Grid_ES_r,     marker='v', linestyle='-', color='m',       markersize=13, label='GridSearch-ES')
plt.plot(xpos[:3], l2c_m,      marker='*', linestyle='-', color='red',        markersize=18, label='Learn2Clean')
plt.plot(xpos, BugDoc_m,   marker='d', linestyle='-', color='blueviolet', markersize=18, label='BugDoc')
plt.plot(xpos, PipeLens_m, marker='s', linestyle='-', color='black',      markersize=18, label='PipeLens')
#plt.plot(xpos, pipelens_o_r, marker='+', linestyle='-', color='g',      markersize=18, label='PipeLens_O')

plt.xlabel('Goal Utility', labelpad=0, fontsize=fsize/1)
#plt.xlabel('Percentile', labelpad=0, fontsize=fsize/1.2)
plt.ylabel('#iterations', labelpad=0, fontsize=fsize/1)
plt.legend(fontsize=fsize/1, loc='best', ncol=1)

ys = [np.asarray(a) for a in [Grid_w, l2c_w, BugDoc_w, PipeLens_w] if a is not None]
max_y = np.nanmax(np.concatenate(ys)) if ys else 0


ax = plt.gca()
ax.legend(fontsize=fsize/1.2,
    loc='upper left',                 # anchor point on the legend box
    ncol=1,
    bbox_to_anchor=(0.4, .42)
)

# --- Let Matplotlib choose tick positions; just format them to 2 decimals ---
# (Do NOT call ax.set_xticks() with no args; that caused the error.)
ax.xaxis.set_major_formatter(mticker.FormatStrFormatter('%.2f'))
ax.set_xticks(x_en)
ax.set_xticklabels(labels)

# Optional: keep the view tight around your x data (still lets ticks be chosen automatically)
# ax.set_xlim(min(x_en), max(x_en))
# or:
# ax.margins(x=0.05)

ax.set_yscale('log')
ax.yaxis.set_major_locator(LogLocator(base=10))
ax.yaxis.set_minor_locator(LogLocator(base=10, subs=np.arange(2,10)*0.1, numticks=10))
ax.yaxis.set_major_formatter(LogFormatterMathtext(base=10))  # shows 10^n
ax.yaxis.set_minor_formatter(NullFormatter())

plt.tight_layout()
plt.savefig(file_path, format='pdf', dpi=1600, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
gg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[479], line 1
# ----> 1 gg
#
# NameError: name 'gg' is not defined

# %% [markdown]
# ## Regression

# %%
task='regression'
case='easier'

# %% [markdown]
# #### median

# %%
Grid_m=[23, 44, 68, 113]
l2c_m=[11,11,23,32]
BugDoc_m=[36, 44, 48, 58]
PipeLens_m=[3, 6, 8, 9]

# %% [markdown]
# #### worse

# %%
Grid_w=[42, 131, 263,310]
l2c_w=[22,32,34,54]
BugDoc_w=[38, 58, 58, 129]
PipeLens_w=[8, 11, 13, 17]

# %% [markdown]
# #### tight

# %%
Grid_t=[36, 133, 145, 310]
l2c_t=[21,32,41,54]
BugDoc_t=[38,38,38,38]
PipeLens_t=[3,9,10,17]

# %% [markdown]
# #### relaxed

# %%
Grid_r=[22,23,35,42]
l2c_r=[2,11,13,42]
BugDoc_r=[24,24,24,24]
PipeLens_r=[1,3,5,8]

# %%
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import matplotlib.pyplot as plot  # for plot.rcParams usage
from matplotlib.ticker import LogLocator, LogFormatterMathtext, NullFormatter

fsize = 20
params = {'legend.fontsize': fsize, 'legend.handlelength': 2}
plot.rcParams.update(params)

font = {'family': "sans serif", 'size': fsize}
matplotlib.rc('font', **font)

# --- Save path ---
folder_path = '/Users/hasan89/Documents/PipeLens_Plot/Regression'
file_name = f"{task}_{case}.pdf"

os.makedirs(folder_path, exist_ok=True)
file_path = os.path.join(folder_path, file_name)

# ... your existing code above ...

plt.figure(figsize=(6, 5))
plt.xticks(fontsize=fsize/1.2)
plt.yticks(fontsize=fsize/1.2)

#x_en = [0.85, 0.92, 0.97, 1.00]
x_en = [25, 50, 75, 100]

# Map to evenly spaced positions
labels = [f"{v}" for v in x_en]
#labels = [f"{v:.2f}" for v in x_en]
xpos = np.arange(len(x_en))  # 0,1,2,3 (equally spaced)
#xpos = x_en

# Plot against xpos (not x_en)
plt.plot(xpos, Grid_r,     marker='o', linestyle='-', color='navy',       markersize=18, label='GridSearch-ES')
plt.plot(xpos, l2c_r,      marker='*', linestyle='-', color='red',        markersize=18, label='Learn2Clean')
plt.plot(xpos, BugDoc_r,   marker='d', linestyle='-', color='blueviolet', markersize=18, label='BugDoc')
plt.plot(xpos, PipeLens_r, marker='s', linestyle='-', color='black',      markersize=18, label='PipeLens')

#lt.xlabel('Goal Utility', labelpad=0, fontsize=fsize/1.2)
plt.xlabel('Percentile', labelpad=0, fontsize=fsize/1.2)
plt.ylabel('#iterations', labelpad=0, fontsize=fsize/1.2)
plt.legend(fontsize=fsize/1.2, loc='best', ncol=1)

ys = [np.asarray(a) for a in [Grid_w, l2c_w, BugDoc_w, PipeLens_w] if a is not None]
max_y = np.nanmax(np.concatenate(ys)) if ys else 0

ax = plt.gca()
ax.legend(fontsize=fsize/1.2,
    loc='upper left',                 # anchor point on the legend box
    ncol=1,
    bbox_to_anchor=(0.05, .60)
)

# --- Let Matplotlib choose tick positions; just format them to 2 decimals ---
# (Do NOT call ax.set_xticks() with no args; that caused the error.)
ax.xaxis.set_major_formatter(mticker.FormatStrFormatter('%.2f'))
ax.set_xticks(xpos)
ax.set_xticklabels(labels)

# Optional: keep the view tight around your x data (still lets ticks be chosen automatically)
# ax.set_xlim(min(x_en), max(x_en))
# or:
# ax.margins(x=0.05)

ax.set_yscale('log')
ax.yaxis.set_major_locator(LogLocator(base=10))
ax.yaxis.set_minor_locator(LogLocator(base=10, subs=np.arange(2,10)*0.1, numticks=10))
ax.yaxis.set_major_formatter(LogFormatterMathtext(base=10))  # shows 10^n
ax.yaxis.set_minor_formatter(NullFormatter())

plt.tight_layout()
plt.savefig(file_path, format='pdf', dpi=1600, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
gg

# %%
task='accuracy'
case='tight'

# %% [markdown]
# ## Classification

# %%
Grid_m=[31, 62, 115, 213]
l2c_m=[8,8,8,17]
BugDoc_m=[33, 43, 59, 59]
PipeLens_m=[1, 2, 2, 6]

# %%
Grid_w=[77, 213, 316, 677]
l2c_w=[15,15,19,25]
BugDoc_w=[52, 72, 72, 122]
PipeLens_w=[1, 2, 8, 9]

# %%
Grid_t=[213, 327, 616]
l2c_t=[11,17,19,25]
BugDoc_t=[34,59,72,122]
PipeLens_t=[1,1,2,9]

# %%
Grid_r=[21,31,43,77]
l2c_r=[1,8,12,15]
BugDoc_r=[33,33,45,72]
PipeLens_r=[1,1,1,1]

# %%
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import matplotlib.pyplot as plot  # for plot.rcParams usage
from matplotlib.ticker import LogLocator, LogFormatterMathtext, NullFormatter

fsize = 20
params = {'legend.fontsize': fsize, 'legend.handlelength': 2}
plot.rcParams.update(params)

font = {'family': "sans serif", 'size': fsize}
matplotlib.rc('font', **font)

# --- Save path ---
folder_path = '/Users/hasan89/Documents/PipeLens_Plot/Regression'
file_name = f"{task}_{case}.pdf"

os.makedirs(folder_path, exist_ok=True)
file_path = os.path.join(folder_path, file_name)

# ... your existing code above ...

plt.figure(figsize=(6, 5))
plt.xticks(fontsize=fsize/1.2)
plt.yticks(fontsize=fsize/1.2)

#x_en = [0.93, 0.94, 0.95, 0.96]
x_en = [25, 50, 75, 100]

# Map to evenly spaced positions
labels = [f"{v}" for v in x_en]
#labels = [f"{v:.2f}" for v in x_en]
xpos = np.arange(len(x_en))  # 0,1,2,3 (equally spaced)
#xpos = x_en

# Plot against xpos (not x_en)
plt.plot(xpos[:3], Grid_t,     marker='o', linestyle='-', color='navy',       markersize=18, label='GridSearch-ES')
plt.plot(xpos, l2c_t,      marker='*', linestyle='-', color='red',        markersize=18, label='Learn2Clean')
plt.plot(xpos, BugDoc_t,   marker='d', linestyle='-', color='blueviolet', markersize=18, label='BugDoc')
plt.plot(xpos, PipeLens_t, marker='s', linestyle='-', color='black',      markersize=18, label='PipeLens')

#lt.xlabel('Goal Utility', labelpad=0, fontsize=fsize/1.2)
plt.xlabel('Percentile', labelpad=0, fontsize=fsize/1.2)
plt.ylabel('#iterations', labelpad=0, fontsize=fsize/1.2)
plt.legend(fontsize=fsize/1.2, loc='best', ncol=1)

ys = [np.asarray(a) for a in [Grid_w, l2c_w, BugDoc_w, PipeLens_w] if a is not None]
max_y = np.nanmax(np.concatenate(ys)) if ys else 0

ax = plt.gca()
ax.legend(fontsize=fsize/1.2,
    loc='upper left',                 # anchor point on the legend box
    ncol=1,
    bbox_to_anchor=(0.05, .60)
)

# --- Let Matplotlib choose tick positions; just format them to 2 decimals ---
# (Do NOT call ax.set_xticks() with no args; that caused the error.)
ax.xaxis.set_major_formatter(mticker.FormatStrFormatter('%.2f'))
ax.set_xticks(xpos)
ax.set_xticklabels(labels)

# Optional: keep the view tight around your x data (still lets ticks be chosen automatically)
# ax.set_xlim(min(x_en), max(x_en))
# or:
# ax.margins(x=0.05)

ax.set_yscale('log')
ax.yaxis.set_major_locator(LogLocator(base=10))
ax.yaxis.set_minor_locator(LogLocator(base=10, subs=np.arange(2,10)*0.1, numticks=10))
ax.yaxis.set_major_formatter(LogFormatterMathtext(base=10))  # shows 10^n
ax.yaxis.set_minor_formatter(NullFormatter())

plt.tight_layout()
plt.savefig(file_path, format='pdf', dpi=1600, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib as mpl

# -------- Do NOT use LaTeX; keep mathtext --------
mpl.rcParams['text.usetex'] = False
mpl.rcParams['mathtext.default'] = 'regular'
mpl.rcParams['font.family'] = 'sans-serif'

# ================= Font & saving config =================
fsize = 26
params = {'legend.fontsize': fsize, 'legend.handlelength': 2}
matplotlib.rcParams.update(params)

# use sans-serif + global sizes
matplotlib.rc('font', family='sans-serif', size=fsize)
matplotlib.rcParams.update({
    'axes.titlesize': fsize,
    'axes.labelsize': fsize,
    'xtick.labelsize': fsize-2,
    'ytick.labelsize': fsize-2,
})

# set these before saving
task = globals().get('task', 'Runtime')
case = globals().get('case', 'AllMethods')

folder_path = '/Users/hasan89/Documents/PipeLens_Plot'
file_name = f"complexity_simulation.pdf"
os.makedirs(folder_path, exist_ok=True)
file_path = os.path.join(folder_path, file_name)

# ================= Scenario constants =================
a = 1e-4
b = 1e-8
c = 5e-5

K_PIPELENS = 2
N_BUGDOC   = 58
N_L2C      = 15
N_GRID     = 277

FIX_PIPELENS_ONCE = 70.0
FIX_BUGDOC_PER    = 7.0
FIX_L2C_PER       = 4.5
FiX_GRID_PER      = .25  # (kept as-is)

x = np.geomspace(1e-1, 1e6, 60)  # >0 for log scale

# ================= Per-model training times =================
def train_time_linear(x):     return a * x
def train_time_quadratic(x):  return b * x**2
def train_time_realistic(x):  return c * x * np.log2(x + 1.0)

# ================= Total time per framework =================
def total_time_pipelens(t_train):
    return FIX_PIPELENS_ONCE + K_PIPELENS * t_train(x)

def total_time_bugdoc(t_train):
    fixed = N_BUGDOC * FIX_BUGDOC_PER
    return fixed + N_BUGDOC * t_train(x)

def total_time_l2c(t_train):
    fixed = N_L2C * FIX_L2C_PER
    return fixed + N_L2C * t_train(x)

def total_time_grid(t_train):
    fixed = N_GRID * FiX_GRID_PER
    return fixed + N_GRID * t_train(x)

# --- framework labels, colors, and line styles ---
frameworks = [
    ("PipeLens",        r"$\mathrm{PipeLens}$",         total_time_pipelens),
    ("BugDoc",          r"$\mathrm{BugDoc}$",           total_time_bugdoc),
    ("Learn2Clean",     r"$\mathrm{Learn2Clean}$",      total_time_l2c),
    ("GridSearch-ES",   "GridSearch-ES",                total_time_grid),
]

colors = {
    "PipeLens": "black",
    "BugDoc": "blueviolet",
    "Learn2Clean": "red",
    "GridSearch-ES": "g",
}

# Different dashed line styles for each framework
linestyles = {
    "PipeLens": (0, ()),                  # solid
    "BugDoc": (0, (5, 2)),                # dashed
    "Learn2Clean": (0, (3, 2, 1, 2)),     # dash-dot-dot
    "GridSearch-ES": (0, (1, 1)),         # dotted
}

line_width = 3.0

# --- subplot titles (Big-O only) ---
complexities = [
    (r"$\mathcal{O}(n)$",         train_time_linear),
    (r"$\mathcal{O}(n^{2})$",     train_time_quadratic),
    (r"$\mathcal{O}(n\log n)$",   train_time_realistic),
]

# ================= Plot: 1×3 subplots =================
fig, axes = plt.subplots(1, 3, figsize=(18, 4.8), sharex=True, sharey=True)

for ax, (title, tfunc) in zip(axes, complexities):
    for key, label, tfw in frameworks:
        y = tfw(tfunc)
        ax.plot(
            x, y,
            label=label,
            linewidth=line_width,
            color=colors[key],
            linestyle=linestyles[key]
        )
    ax.set_xscale("log")
    ax.set_yscale("log")
    ax.set_title(title)
    ax.set_xlabel(r"$n$")

axes[0].set_ylabel(r"Required Time (s)")

# One legend for all
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, loc="upper center",
           ncol=len(frameworks), bbox_to_anchor=(0.5, 1.12))

plt.tight_layout()

# ===== Save PDF =====
plt.savefig(file_path, format='pdf', bbox_inches='tight')
print(f"Saved plot to: {file_path}")

plt.show()
# Out:
# Saved plot to: /Users/hasan89/Documents/PipeLens_Plot/complexity_simulation.pdf

# %%
folder_path = '/Users/hasan89/Documents/PipeLens_Plot'
file_name = f"profile_importance.pdf"
os.makedirs(folder_path, exist_ok=True)
file_path = os.path.join(folder_path, file_name)

datasets = ['Fairness', 'Classification', 'Regression']

methods = ['Core-ML', 'Core-ML+Fairness', 'Core-ML+Classification', 'Core-ML+Regression', 'All']
colors = ['#4C72B0', '#55A868', '#C44E52', '#8172B3', '#FF9F1C']


required_time_dataset_1 = [41, 38, 40, 41, 38]
required_time_dataset_3 = [11, 13, 11, 10, 13]
required_time_dataset_2 = [16, 19, 16,16, 19]
# required_time_dataset_4 = [2.41, 2.51, 1.94, 2.386, 1.36]
# required_time_dataset_5 = [0.8981, 0.927, 0.5894, 0.889, 0.4502]
# required_time_dataset_6 = [1.708, 1.969, 1.29, 1.43, 0.632]


required_times = [required_time_dataset_1, required_time_dataset_3, required_time_dataset_2]


#hatch_patterns = ['/', '\\', '*', '\-', 'x']


n_datasets = len(datasets)
n_methods = len(methods)


bar_width = 0.15
gap = 0.2
index = np.arange(n_datasets) * (n_methods * bar_width + gap) 


plt.figure(figsize=(18, 5))


for i, (method, color) in enumerate(zip(methods, colors)):
    plt.bar(index + i * bar_width, [time[i] for time in required_times], 
            bar_width, label=method, color=color, edgecolor='black')




plt.ylabel('Time Taken (s)', fontsize=20)
plt.xticks(index + bar_width * (n_methods - 1) / 2, datasets, fontsize=20)
plt.legend(fontsize=20, bbox_to_anchor=(0.5, 1), loc='lower center', ncol=n_methods)



plt.gca().set_facecolor('white')
plt.tight_layout()
plt.savefig(file_path, format='pdf', dpi=1600, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %% [markdown]
# ## Efficiency

# %% [markdown]
# #### Adult

# %%
method=['pipelens', 'Grid', 'Learn2Clean', 'BugDoc']
time=[77, 383, 193, 825]

# %% [markdown]
# #### Hmda

# %%
method=['pipelens', 'Grid', 'Learn2Clean', 'BugDoc']
time=[10, 5, 0.8 ,59]

# %% [markdown]
# #### Housing

# %%
method=['pipelens','Grid', 'Learn2Clean', 'BugDoc']
time=[20, 7, 1.2,101]

# %%
method=['PipeLens','Grid', 'Learn2Clean', 'BugDoc']
adult=[77, 383, 193, 825]
hmda=[10, 5, 0.8 ,59]
housing=[20, 7, 1.2,101]

# %%
fsize = 20
params = {'legend.fontsize': fsize, 'legend.handlelength': 2}
plot.rcParams.update(params)

font = {'family': "sans serif", 'size': fsize}
matplotlib.rc('font', **font)

# --- Save path ---
folder_path = '/Users/hasan89/Documents/PipeLens_Plot/Efficiency'
file_name = f"efficiency.pdf"

os.makedirs(folder_path, exist_ok=True)
file_path = os.path.join(folder_path, file_name)

import os
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

datasets = ['Fairness','Accuracy','Regression']

colors = ['#4C72B0', '#55A868', '#C44E52', '#8172B3']




required_times = [adult, hmda, housing]


hatch_patterns = ['/', '\\', '*']


n_datasets = len(datasets)
n_methods = len(method)


bar_width = 0.2
gap = 0.2
index = np.arange(n_datasets) * (n_methods * bar_width + gap) 


plt.figure(figsize=(8, 3.5))


for i, (method, color, hatch) in enumerate(zip(method, colors, hatch_patterns)):
    plt.bar(index + i * bar_width, [time[i] for time in required_times], 
            bar_width, label=method, color=color, edgecolor='black', hatch=hatch)




plt.ylabel('Time Taken (s)', fontsize=20)
plt.xticks(index + bar_width * (n_methods - 1) / 2, datasets, fontsize=20)
plt.legend(fontsize=20, bbox_to_anchor=(0.5, 1), loc='lower center', ncol=n_methods)



plt.gca().set_facecolor('white')
plt.tight_layout()
plt.savefig(file_path, format='pdf', dpi=1600, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %% [markdown]
# ## Ablation

# %% [markdown]
# ## Historical

# %%
grid=[65,82,71,40]
pipelens_o=[31,24, 24, 4]
pipelens_main=[5,2,2,2]
pipelens_pro=[15, 11, 5, 5]

# %%
font = {'family': "sans serif", 'size': fsize}
matplotlib.rc('font', **font)

# --- Save path ---
folder_path = '/Users/hasan89/Documents/PipeLens_Plot/Ablation'
file_name = f"historical.pdf"

os.makedirs(folder_path, exist_ok=True)
file_path = os.path.join(folder_path, file_name)

import os
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
s_size = [0.05, 0.1, 0.2, 0.3]
labels = [f"{v:.2f}" for v in s_size]
#s_sizes = np.arange(len(s_size))
s_sizes=s_size

plt.figure(figsize=(6, 5)) # in inches!
plt.xticks(fontsize= fsize/1.2)
plt.yscale("log")

plt.plot(s_sizes, pipelens_pro, 'k-x', label='PipeLens_O',color='forestgreen',markersize=18)
plt.plot(s_sizes, grid, 'k-o',label='PipeLens_P',color='navy',markersize=18)
plt.plot(s_sizes, pipelens_main, 'k-s',label='PipeLens',color='black',markersize=18)
plt.plot(s_sizes, pipelens_o, 'k-v', label='GridSearch-ES',color='salmon',markersize=18)
plt.legend(loc='upper right')

plt.xlabel('Historical Dataset Size',labelpad=0, fontsize=fsize/1.2)
plt.ylabel('#iterations',labelpad=0, fontsize=fsize/1.2)
plt.savefig('MLfigures/historical_sample_q4.pdf')

ax = plt.gca()
ax.legend(
    fontsize=fsize/1,
    loc='upper left',     # anchor point on the legend box
    ncol=1,
    bbox_to_anchor=(0.24, .95)
)

# Equally spaced ticks with labels from x_en
ax = plt.gca()
ax.set_xticks(s_sizes)
ax.set_xticklabels(labels)
plt.tight_layout()  
plt.savefig(file_path, format='pdf', dpi=1600, bbox_inches='tight', pad_inches=0.1)
plt.show()
# Out:
# /var/folders/bq/9z5f9vts0_1_8bx9mwv1gwfm0000gp/T/ipykernel_34633/924950431.py:23: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-x" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(s_sizes, pipelens_pro, 'k-x', label='PipeLens_O',color='forestgreen',markersize=18)
# /var/folders/bq/9z5f9vts0_1_8bx9mwv1gwfm0000gp/T/ipykernel_34633/924950431.py:24: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-o" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(s_sizes, grid, 'k-o',label='PipeLens_P',color='navy',markersize=18)
# /var/folders/bq/9z5f9vts0_1_8bx9mwv1gwfm0000gp/T/ipykernel_34633/924950431.py:25: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-s" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(s_sizes, pipelens_main, 'k-s',label='PipeLens',color='black',markersize=18)
# /var/folders/bq/9z5f9vts0_1_8bx9mwv1gwfm0000gp/T/ipykernel_34633/924950431.py:26: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-v" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(s_sizes, pipelens_o, 'k-v', label='GridSearch-ES',color='salmon',markersize=18)

# %% [markdown]
# ## Space_size

# %%
grid=[45,50,62, 136]
pipelens_o=[4,10,10,10]
pipelens_main=[2,4,2,2]
pipelens_pro=[8, 10, 13, 13]

# %%
fsize=20
font = {'family': "sans serif", 'size': fsize}
matplotlib.rc('font', **font)

# --- Save path ---
folder_path = '/Users/hasan89/Documents/PipeLens_Plot/Ablation'
file_name = f"space_size.pdf"

os.makedirs(folder_path, exist_ok=True)
file_path = os.path.join(folder_path, file_name)

import os
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
s_size = [360, 720, 1440, 2800]
labels = [f"{v:.0f}" for v in s_size]
s_sizes = s_size

plt.figure(figsize=(6, 5)) # in inches!
plt.xticks(fontsize= fsize/1.2)
#plt.yscale("log")

plt.plot(s_sizes, pipelens_pro, 'k-x', label='PipeLens_O',color='forestgreen',markersize=18)
plt.plot(s_sizes, grid, 'k-o',label='PipeLens_P',color='navy',markersize=18)
plt.plot(s_sizes, pipelens_main, 'k-s',label='PipeLens',color='black',markersize=18)
plt.plot(s_sizes, pipelens_o, 'k-v', label='GridSearch-ES',color='salmon',markersize=18)
plt.legend(loc='upper right')

plt.xlabel('Search Space Size',labelpad=0, fontsize=fsize/1.2)
plt.ylabel('#iterations',labelpad=0, fontsize=fsize/1.2)

plt.legend(fontsize=fsize/1, loc='best', ncol=1)
ax = plt.gca()
ax.legend(
    fontsize=fsize/1,
    loc='upper left',     # anchor point on the legend box
    ncol=1,
    bbox_to_anchor=(0.2, 1.01)
)

# Equally spaced ticks with labels from x_en
ax = plt.gca()
ax.set_xticks(s_sizes)
ax.set_xticklabels(labels)
plt.tight_layout()  
plt.savefig(file_path, format='pdf', dpi=1600, bbox_inches='tight', pad_inches=0.1)
plt.show()
# Out:
# /var/folders/bq/9z5f9vts0_1_8bx9mwv1gwfm0000gp/T/ipykernel_34633/556146451.py:23: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-x" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(s_sizes, pipelens_pro, 'k-x', label='PipeLens_O',color='forestgreen',markersize=18)
# /var/folders/bq/9z5f9vts0_1_8bx9mwv1gwfm0000gp/T/ipykernel_34633/556146451.py:24: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-o" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(s_sizes, grid, 'k-o',label='PipeLens_P',color='navy',markersize=18)
# /var/folders/bq/9z5f9vts0_1_8bx9mwv1gwfm0000gp/T/ipykernel_34633/556146451.py:25: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-s" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(s_sizes, pipelens_main, 'k-s',label='PipeLens',color='black',markersize=18)
# /var/folders/bq/9z5f9vts0_1_8bx9mwv1gwfm0000gp/T/ipykernel_34633/556146451.py:26: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-v" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(s_sizes, pipelens_o, 'k-v', label='GridSearch-ES',color='salmon',markersize=18)

# %%
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# -----------------------
# Font settings (same spirit as yours)
# -----------------------
fsize = 20
font = {'family': "sans serif", 'size': fsize}
matplotlib.rc('font', **font)

# -----------------------
# Data (yours)
# -----------------------
x = np.linspace(0.02, 0.2, 19)  # Utility Threshold

q  = [46, 43, 37, 37, 32, 27, 26, 27, 21, 19, 13, 13, 9, 6, 3, 1, 2, 2, 1]
q1 = [34, 31, 31, 28, 27, 26, 22, 22, 19, 12, 10, 9, 5, 2, 3, 1, 1, 1, 1]
q3 = [52, 48, 39, 39, 39, 32, 29, 33, 33, 23, 22, 19, 18, 12, 9, 5, 3, 3, 3]

# -----------------------
# Reverse x as 1-x AND make everything start "reversely"
# -----------------------
x_plot = 1 - x

# Sort by x_plot so the curve starts from the smallest x_plot (left) to largest (right)
order = np.argsort(x_plot)

x_plot = x_plot[order]
q  = np.array(q)[order]
q1 = np.array(q1)[order]
q3 = np.array(q3)[order]

# -----------------------
# Save path
# -----------------------
folder_path = '/Users/hasan89/Documents/PipeLens_Plot/Ablation'
file_name = "mean_iqr_plot_20points_pretty_reverse.pdf"
os.makedirs(folder_path, exist_ok=True)
file_path = os.path.join(folder_path, file_name)

# -----------------------
# Plot (keep everything same style)
# -----------------------
fig, ax = plt.subplots(figsize=(6.4, 5.2))

# Subtle axis styling (cleaner than default grid)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='both', which='major', labelsize=fsize/1.2)

# IQR shaded band
ax.fill_between(
    x_plot, q1, q3,
    alpha=0.22,
    label='IQR'
)

# Mean line on top (clear emphasis)
ax.plot(
    x_plot, q,
    marker='s',
    linewidth=2.8,
    markersize=7.5,
    label='Median',
    color='black'
)

# Axes labels
ax.set_xlabel('Utility Threshold', labelpad=6, fontsize=fsize/1.2)
ax.set_ylabel('# of iterations', labelpad=6, fontsize=fsize/1.2)

# Better tick formatting (no crowding)
ax.xaxis.set_major_locator(mticker.MaxNLocator(6))
ax.yaxis.set_major_locator(mticker.MaxNLocator(6))

# IMPORTANT: Format ticks to show values of (1 - x_plot) i.e., original threshold
ax.xaxis.set_major_formatter(mticker.FuncFormatter(lambda val, pos: f"{val:.2f}"))

# Light grid (paper-friendly)
ax.grid(True, which='major', linestyle='--', linewidth=0.8, alpha=0.35)

# Legend (your anchored style, but cleaner placement)
ax.legend(
    fontsize=fsize/1,
    loc='upper left',
    bbox_to_anchor=(0.2, 1.02),
    frameon=False
)

plt.tight_layout()
plt.savefig(file_path, format='pdf', dpi=1600, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# -----------------------
# Font settings (same spirit as yours)
# -----------------------
fsize = 20
font = {'family': "sans serif", 'size': fsize}
matplotlib.rc('font', **font)

# -----------------------
# Synthetic Data (20 points)
# -----------------------
np.random.seed(4)

x = np.linspace(4, 19, 15)                  # Utility Threshold
q = [16, 12, 10, 14, 14, 19, 22, 28, 31, 31, 34, 36, 39, 39, 39]
q1= [12, 12, 9, 10, 9, 14, 17, 20, 24, 29, 29, 31, 31, 35, 36]
q3 = [27, 19, 16, 24, 28, 28, 34, 33, 33, 39, 47, 52, 58, 59, 59]            # Mean iterations (decreasing)



# -----------------------
# Save path
# -----------------------
folder_path = '/Users/hasan89/Documents/PipeLens_Plot/Ablation'
file_name = "mean_iqr_plot_20points_pretty.pdf"
os.makedirs(folder_path, exist_ok=True)
file_path = os.path.join(folder_path, file_name)

# -----------------------
# Plot (more visually attractive, still clean/paper-ready)
# -----------------------
fig, ax = plt.subplots(figsize=(6.4, 5.2))

# Subtle axis styling (cleaner than default grid)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='both', which='major', labelsize=fsize/1.2)

# IQR shaded band
ax.fill_between(
    x, q1, q3,
    alpha=0.22,
    label='IQR'
)

# Mean line on top (clear emphasis)
ax.plot(
    x, q,
    marker='s',
    linewidth=2.8,
    markersize=7.5,
    label='Mean',
    color='black'
)

# Axes labels
ax.set_xlabel('Pipeline Size', labelpad=6, fontsize=fsize/1.2)
ax.set_ylabel('# of iterations', labelpad=6, fontsize=fsize/1.2)

# Better tick formatting (no crowding)
ax.xaxis.set_major_locator(mticker.MaxNLocator(6))
ax.yaxis.set_major_locator(mticker.MaxNLocator(6))
ax.xaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f'))

# Light grid (paper-friendly)
ax.grid(True, which='major', linestyle='--', linewidth=0.8, alpha=0.35)

# Legend (your anchored style, but cleaner placement)
ax.legend(
    fontsize=fsize/1,
    loc='upper left',
    bbox_to_anchor=(0.2, 1.02),
    frameon=False
)

plt.tight_layout()
plt.savefig(file_path, format='pdf', dpi=1600, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
folder_path = '/Users/hasan89/Library/CloudStorage/OneDrive-purdue.edu/Ph.D. Resource/Research Code/Plots/Efficiency'
file_name = 'public.pdf'

os.makedirs(folder_path, exist_ok=True)
file_path = os.path.join(folder_path, file_name)

methods = ['Core-ML', 'ML+F','ML+C', 'ML+R', 'ALL']
required_tme = [42, 38, 39, 42, 38]

plt.figure(figsize=(8, 5.5))

#hatch_patterns = ['/', '\\', 'x', '/-']
colors = ['#4C72B0', '#55A868', '#C44E52', '#8172B3', '#64B5CD']

bars = plt.bar(methods, required_tme, color=colors, edgecolor='black', linewidth=1)


plt.xlabel('Profile Selection', fontsize=25)
plt.ylabel('# of iterations', fontsize=25)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.gca().set_facecolor('white')

plt.tight_layout()
plt.savefig(file_path, format='pdf', dpi=600)
plt.show()
