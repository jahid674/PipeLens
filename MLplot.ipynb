# %%
import matplotlib as plt
import pylab as plot
import matplotlib
import os
import numpy as np

# %% [markdown]
# ## Fairness

# %%
task='fairness'
case='easier'

# %% [markdown]
# #### Median

# %%
Grid_m=[2, 3, 15, 45]
#Grid_ES_m=[2, 3, 15, 45]
l2c_m=[3,5]
BugDoc_m=[32, 33, 42]
PipeLens_m=[1, 1, 2, 3]

# %% [markdown]
# #### Worst

# %%
Grid_w=[8, 14, 103, 261]
#Grid_ES_w=[8, 14, 103, 261]
l2c_w=[25, 25]
BugDoc_w=[33,41, 42]
PipeLens_w=[1, 3, 3, 16]

# %% [markdown]
# #### Tight fgoal

# %%
Grid_t=[22, 45, 84, 261]
#Grid_ES_t=[22, 45, 84, 261]
#BugDoc_t=[18,18,18,18]
PipeLens_t=[2,3,4,16]

# %% [markdown]
# #### Relaxed fgoal

# %%
Grid_r=[1,2,3,8]
#Grid_ES_r=[1,2,3,8]
l2c_r=[1,3,9,25]
BugDoc_r=[31,32,32,33]
PipeLens_r=[1,1,1,1]

# %%
fsize = 20
params = {'legend.fontsize': fsize, 'legend.handlelength': 2}
plot.rcParams.update(params)

font = {'family': "sans serif", 'size': fsize}
matplotlib.rc('font', **font)

# --- Save path ---
folder_path = '/Users/hasan89/Documents/PipeLens_Plot/Fairness'
file_name = f"{task}_{case}.pdf"

os.makedirs(folder_path, exist_ok=True)
file_path = os.path.join(folder_path, file_name)

import os
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# ... your existing code above ...

plt.figure(figsize=(6, 5))
plt.xticks(fontsize=fsize/1.2)
plt.yticks(fontsize=fsize/1.2)

x_en = [0.84, 0.87, 0.94, 0.95]
x_en = [25, 50, 75, 100]

# Map to evenly spaced positions
labels = [f"{v:.0f}" for v in x_en]
#labels = [f"{v:.2f}" for v in x_en]
xpos = np.arange(len(x_en))  # 0,1,2,3 (equally spaced)

# Plot against xpos (not x_en)
plt.plot(xpos, Grid_r,     marker='o', linestyle='-', color='navy',       markersize=13, label='GridSearch-ES')
#plt.plot(xpos, Grid_ES_r,     marker='v', linestyle='-', color='m',       markersize=13, label='GridSearch-ES')
plt.plot(xpos, l2c_r,  marker='*', linestyle='-', color='red',        markersize=10, label='Learn2Clean')
plt.plot(xpos, BugDoc_r,   marker='d', linestyle='-', color='blueviolet', markersize=10, label='BugDoc')
plt.plot(xpos, PipeLens_r, marker='s', linestyle='-', color='black',      markersize=10, label='PipeLens')

#plt.xlabel('Goal Utility', labelpad=0, fontsize=fsize/1.2)
plt.xlabel('Percentile', labelpad=0, fontsize=fsize/1.2)
plt.ylabel('#iterations', labelpad=0, fontsize=fsize/1.2)
plt.legend(fontsize=fsize/1.4, loc='best', ncol=1)

# Equally spaced ticks with labels from x_en
ax = plt.gca()
ax.set_xticks(xpos)
ax.set_xticklabels(labels)
import numpy as np
from matplotlib.ticker import LogLocator, LogFormatterMathtext, NullFormatter
ys = [np.asarray(a) for a in [Grid_w, l2c_w, BugDoc_w, PipeLens_w] if a is not None]
max_y = np.nanmax(np.concatenate(ys)) if ys else 0

ax = plt.gca()
ax.set_xticks(xpos)
ax.set_xticklabels(labels)

if max_y > 100:
    ax.set_yscale('log')
    ax.yaxis.set_major_locator(LogLocator(base=10))
    ax.yaxis.set_minor_locator(LogLocator(base=10, subs=np.arange(2,10)*0.1, numticks=10))
    ax.yaxis.set_major_formatter(LogFormatterMathtext(base=10))  # shows 10^n
    ax.yaxis.set_minor_formatter(NullFormatter())

plt.tight_layout()  
plt.savefig(file_path, format='pdf', dpi=1600, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
gg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[208], line 1
# ----> 1 gg
#
# NameError: name 'gg' is not defined

# %% [markdown]
# ## Regression

# %%
task='regression'
case='easier'

# %% [markdown]
# #### median

# %%
Grid_m=[2, 3, 4, 9]
l2c_m=[1,1,2,3]
BugDoc_m=[24, 24, 38, 38]
PipeLens_m=[1, 1, 1, 1]

# %% [markdown]
# #### worse

# %%
Grid_w=[19, 17, 17,34]
l2c_w=[22,22,24,24]
BugDoc_w=[38, 39, 42, 49]
PipeLens_w=[1, 1, 1, 11]

# %% [markdown]
# #### tight

# %%
Grid_t=[4, 9, 18, 34]
l2c_t=[1,3,11,24]
BugDoc_t=[24,24,24,24]
PipeLens_t=[1,1,1,11]

# %% [markdown]
# #### relaxed

# %%
Grid_r=[1,2,5,19]
l2c_r=[1,1,2,22]
BugDoc_r=[38,38,38,38]
PipeLens_r=[1,1,1,1]

# %%
fsize = 20
params = {'legend.fontsize': fsize, 'legend.handlelength': 2}
plot.rcParams.update(params)

font = {'family': "sans serif", 'size': fsize}
matplotlib.rc('font', **font)

# --- Save path ---
folder_path = '/Users/hasan89/Documents/PipeLens_Plot/Regression'
file_name = f"{task}_{case}.pdf"

os.makedirs(folder_path, exist_ok=True)
file_path = os.path.join(folder_path, file_name)

import os
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# ... your existing code above ...

plt.figure(figsize=(6, 5))
plt.xticks(fontsize=fsize/1.2)
plt.yticks(fontsize=fsize/1.2)

#x_en = [0.85, 0.92, 0.97, 1.00]
x_en = [25, 50, 75, 100]

# Map to evenly spaced positions
labels = [f"{v:.0f}" for v in x_en]
xpos = np.arange(len(x_en))  # 0,1,2,3 (equally spaced)

# Plot against xpos (not x_en)
plt.plot(xpos, Grid_r,     marker='o', linestyle='-', color='navy',       markersize=13, label='Systematic')
plt.plot(xpos, l2c_r,  marker='*', linestyle='-', color='red',        markersize=10, label='Learn2Clean')
plt.plot(xpos, BugDoc_r,   marker='d', linestyle='-', color='blueviolet', markersize=10, label='BugDoc')
plt.plot(xpos, PipeLens_r, marker='s', linestyle='-', color='black',      markersize=10, label='PipeLens')

#plt.xlabel('Goal Utility', labelpad=0, fontsize=fsize/1.2)
plt.xlabel('Percentile', labelpad=0, fontsize=fsize/1.2)
plt.ylabel('#iterations', labelpad=0, fontsize=fsize/1.2)
plt.legend(fontsize=fsize/1.3, loc='best', ncol=1)

# Equally spaced ticks with labels from x_en
ax = plt.gca()
ax.set_xticks(xpos)
ax.set_xticklabels(labels)
plt.tight_layout()  
plt.savefig(file_path, format='pdf', dpi=1600, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
gg

# %%
task='accuracy'
case='easier'

# %% [markdown]
# ## Classification

# %%
Grid_m=[1, 2, 5, 7]
l2c_m=[2,3,3,4]
BugDoc_m=[33, 33, 33, 49]
PipeLens_m=[1, 1, 1, 1]

# %%
Grid_w=[7, 9, 16, 77]
l2c_w=[15,15,15,15]
BugDoc_w=[72, 72, 72, 72]
PipeLens_w=[1, 1, 8, 9]

# %%
Grid_t=[3, 7, 16, 77]
l2c_t=[1,4,10,15]
BugDoc_t=[45,49,58,72]
PipeLens_t=[1,1,2,9]

# %%
Grid_r=[1,1,3,7]
l2c_r=[1,2,5,15]
BugDoc_r=[33,33,45,72]
PipeLens_r=[1,1,1,1]

# %%
fsize = 20
params = {'legend.fontsize': fsize, 'legend.handlelength': 2}
plot.rcParams.update(params)

font = {'family': "sans serif", 'size': fsize}
matplotlib.rc('font', **font)

# --- Save path ---
folder_path = '/Users/hasan89/Documents/PipeLens_Plot/Accuracy'
file_name = f"{task}_{case}.pdf"

os.makedirs(folder_path, exist_ok=True)
file_path = os.path.join(folder_path, file_name)

import os
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# ... your existing code above ...

plt.figure(figsize=(6, 5))
plt.xticks(fontsize=fsize/1.2)
plt.yticks(fontsize=fsize/1.2)

#x_en = [0.83, 0.84, 0.85, 0.86]
x_en = [25, 50, 75, 100]

# Map to evenly spaced positions
labels = [f"{v:.0f}" for v in x_en]
xpos = np.arange(len(x_en))  # 0,1,2,3 (equally spaced)

# Plot against xpos (not x_en)
plt.plot(xpos, Grid_t,     marker='o', linestyle='-', color='navy',       markersize=13, label='Systematic')
plt.plot(xpos, l2c_t,  marker='*', linestyle='-', color='red',        markersize=10, label='Learn2Clean')
plt.plot(xpos, BugDoc_t,   marker='d', linestyle='-', color='blueviolet', markersize=10, label='BugDoc')
plt.plot(xpos, PipeLens_t, marker='s', linestyle='-', color='black',      markersize=10, label='PipeLens')

#plt.xlabel('Goal Utility', labelpad=0, fontsize=fsize/1.2)
plt.xlabel('Percentile', labelpad=0, fontsize=fsize/1.2)
plt.ylabel('#iterations', labelpad=0, fontsize=fsize/1.2)
plt.legend(fontsize=fsize/1.3, loc='best', ncol=1)

# Equally spaced ticks with labels from x_en
ax = plt.gca()
ax.set_xticks(xpos)
ax.set_xticklabels(labels)
plt.tight_layout()  
plt.savefig(file_path, format='pdf', dpi=1600, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %% [markdown]
# ## Efficiency

# %% [markdown]
# #### Adult

# %%
method=['pipelens', 'Grid', 'Learn2Clean', 'BugDoc']
time=[77, 383, 193, 825]

# %% [markdown]
# #### Hmda

# %%
method=['pipelens', 'Grid', 'Learn2Clean', 'BugDoc']
time=[10, 5, 0.8 ,59]

# %% [markdown]
# #### Housing

# %%
method=['pipelens','Grid', 'Learn2Clean', 'BugDoc']
time=[20, 7, 1.2,101]

# %%
method=['PipeLens','Grid', 'Learn2Clean', 'BugDoc']
adult=[77, 383, 193, 825]
hmda=[10, 5, 0.8 ,59]
housing=[20, 7, 1.2,101]

# %%
fsize = 20
params = {'legend.fontsize': fsize, 'legend.handlelength': 2}
plot.rcParams.update(params)

font = {'family': "sans serif", 'size': fsize}
matplotlib.rc('font', **font)

# --- Save path ---
folder_path = '/Users/hasan89/Documents/PipeLens_Plot/Efficiency'
file_name = f"efficiency.pdf"

os.makedirs(folder_path, exist_ok=True)
file_path = os.path.join(folder_path, file_name)

import os
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

datasets = ['Fairness','Accuracy','Regression']

colors = ['#4C72B0', '#55A868', '#C44E52', '#8172B3']




required_times = [adult, hmda, housing]


hatch_patterns = ['/', '\\', '*']


n_datasets = len(datasets)
n_methods = len(method)


bar_width = 0.2
gap = 0.2
index = np.arange(n_datasets) * (n_methods * bar_width + gap) 


plt.figure(figsize=(8, 3.5))


for i, (method, color, hatch) in enumerate(zip(method, colors, hatch_patterns)):
    plt.bar(index + i * bar_width, [time[i] for time in required_times], 
            bar_width, label=method, color=color, edgecolor='black', hatch=hatch)




plt.ylabel('Time Taken (s)', fontsize=20)
plt.xticks(index + bar_width * (n_methods - 1) / 2, datasets, fontsize=20)
plt.legend(fontsize=20, bbox_to_anchor=(0.5, 1), loc='lower center', ncol=n_methods)



plt.gca().set_facecolor('white')
plt.tight_layout()
plt.savefig(file_path, format='pdf', dpi=1600, bbox_inches='tight', pad_inches=0.1)
plt.show()
