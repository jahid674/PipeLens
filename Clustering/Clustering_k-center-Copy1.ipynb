# %%
import pandas as pd

# %%
f=open('camera_entity_resolution_gt.csv','r')
iter=0
clusters={}
rec_to_clust={}
for line in f:
    line=line.strip()
    line=line.split(',')
    lst=[]
    if line[0] in clusters.keys():
        lst=clusters[line[0]]
    lst.append(line[1])
    clusters[line[0]]=lst
    rec_to_clust[line[1]]=line[0]
    iter+=1
    
size={}
for c in clusters.keys():
    size[c] = len(clusters[c])

sorted_clusters = sorted(size.items(), key=lambda x:x[1], reverse=True)


print (sorted_clusters[:4])
chosen_clusters = (sorted_clusters[:4])
# Out:
# [('"ENTITY#44', 184), ('"ENTITY#23', 178), ('"ENTITY#18', 168), ('"ENTITY#36', 155)]

# %%
import json
lst=[]
for (c,size) in chosen_clusters:
    lst.extend(clusters[c])
    
#print (lst)

record_map={}


for recordid in lst:
    recordid=recordid.replace('"','')
    (source,r_id) = recordid.split('//')
    #print (source,r_id)
    f=open('./2013_camera_specs/'+source+'/'+r_id+'.json','r')
    json_obj = json.load(f)
    record_map[recordid] = json_obj
    #print(json_obj['<page title>'])
    
    
record_lst=list(record_map.keys())

# %%
import random
import re
random.seed(1)
import re
def clean_text(t):
    #t=t.replace('Price','')
    t = re.sub(r'\b\w{1,4}\b', '', t)
    t=t.replace('India','')
    t=t.replace('|','')
    
    t=t.replace('Bangalore','')
    t=t.replace('Hyderabad','')
    t=t.replace('Camera   Battery   Charger','')
    t=t.replace('Digital','')
    t=t.replace('Camera','')
    t=t.replace('135mm','')
    t=t.replace('18 0 MP Digital SLR Camera','')
    t=t.replace('Black','')
    t=re.sub(' +', ' ', t)
    return t
    #if 'Nikon' in t:
    

    
    return t
def get_distance(r1,r2):
    t1=clean_text(r1['<page title>'])
    t2=clean_text(r2['<page title>'])


    words_doc1 = set(t1.lower().split()) 
    words_doc2 = set(t2.lower().split())
    
    
    if 'nikon' in words_doc1 and 'canon' in words_doc2:
        return 1
    
    if 'nikon' in words_doc2 and 'canon' in words_doc1:
        return 1
    
    
    
    intersection = words_doc1.intersection(words_doc2)
    union = words_doc1.union(words_doc2)
        
    return 1 - float(len(intersection)) / len(union)


def assign (centers,records,record_map,assignment,distance):
    
    for r in records:
        #print (r)
        if r not in assignment.keys():
            assignment[r] = centers[0]

            distance [r] = get_distance (record_map[r],record_map[centers[0]])
            continue
            
        min_dist=distance[r]
        
        new_dist = get_distance (record_map[r],record_map[centers[-1]])
        if new_dist<min_dist:
            distance [r] = new_dist
            assignment [r] = centers[-1]
        
    return assignment,distance
    
def k_center_clustering(records,record_map,k):
    i=0
    centers=[records[random.randint(0,len(records))]]
    assignment = {}
    distance ={}
    print ("chosen this",centers[0])
    while len(centers)<k:
        
        #assign
        (assignment,distance) = assign(centers,records,record_map, assignment, distance)
        
        #Pick a center, which is the max value of distance
        
        sorted_distance = sorted(distance.items(), key=lambda x:x[1], reverse=True)
        
        newcenter = sorted_distance [0][0]
        print ("chosen this",newcenter)
        centers.append(newcenter)
        i+=1
    
    (assignment,distance) = assign(centers,records,record_map, assignment, distance)
    
    return centers,assignment

# %%
centers,assignment = k_center_clustering(record_lst,record_map,4)
# Out:
# chosen this www.ebay.com//54560
# chosen this www.ebay.com//56744
# chosen this buy.net//5986
# chosen this www.mypriceindia.com//732

# %%
def get_clusters(assignment):
    clusters={}
    for r in assignment.keys():
        lst=[]
        if assignment[r] in clusters.keys():
            lst=clusters[assignment[r]]
        lst.append(r)
        clusters[assignment[r]]=lst
    return clusters

# %%
clusters=get_clusters(assignment)
tp=0
fp=0
for c in clusters.keys():
    curr=clusters[c]
    i=0
    while i<len(curr):
        j=i+1
        while j<len(curr):
            if rec_to_clust[curr[i]+'"'] == rec_to_clust[curr[j]+'"']:
                tp+=1
            else:
                fp+=1
            
            j+=1
        i+=1
            
print (tp,fp,tp*1.0/(tp+fp))
# Out:
# 45437 44716 0.5039987576675208

# %%
correct=0
incorrect=0

for r in record_lst:
    center_entity_id = rec_to_clust[assignment[r]+'"']
    curr_id = rec_to_clust[r+'"']
    if curr_id==center_entity_id:
        correct+=1
    else:
        incorrect+=1
        print (clean_text(record_map[r]['<page title>']))
        print (clean_text(record_map[assignment[r]]['<page title>']))
    #print (curr_id,center_entity_id)
    
print(incorrect*1.0/(incorrect+correct))


for c in centers:
    print (record_map[c])
    
#Remove tokens which are 3 characters or less! this will make eos ones fail!
#What profiles to use? Fraction of 3 character words!
# Out:
# Nikon D3200 ( ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3100 (- & - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3200 / -300mm - Price comparison & reviews - s - Australia
# Nikon D3100 (- & - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3200 price , Specs Review Valid Delhi, Mumbai, , , Chennai, Kolkata, Ahmedabad, Surat Price-
# Nikon D3100 (- & - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3200 / - & -300mm - Price comparison & reviews - s - Australia
# Nikon D3100 (- & - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3200 / -200mm - Price comparison & reviews - s - Australia
# Nikon D3100 (- & - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3200 / -140mm - Price comparison & reviews - s - Australia
# Nikon D3100 (- & - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3200 (- ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3100 (- & - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3200 (- - & - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3100 (- & - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3200 / - & -200mm - Price comparison & reviews - s - Australia
# Nikon D3100 (- & - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3200 / - - Price comparison & reviews - s - Australia
# Nikon D3100 (- & - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3200 (- ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3100 (- & - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3200 ( - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3100 (- & - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3200 / - - - Lenses (. , ) Price Comparison .
# Nikon D3100 (- & - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3200 (- - & Tamron - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3100 (- & - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3200 / -300mm - Price comparison & reviews - s - Australia
# Nikon D3100 (- & - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3200 - Price comparison & reviews - s - Australia
# Nikon D3100 (- & - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3200 / - & -300mm - Price comparison & reviews - s - Australia
# Nikon D3100 (- & - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3200 (- - & - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3100 (- & - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3200 / - (. , // ) Price Comparison .
# Nikon D3100 (- & - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Nikon D3200 / -105mm - Price comparison & reviews - s - Australia
# Nikon D3100 (- & - ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Canon - Price comparison & reviews - s - Australia
# Canon Megapixel - - - (" - . Optical - Image - Video - - PictBridge - Movie ) Price Comparison .
# Canon ( ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Canon Megapixel - - - (" - . Optical - Image - Video - - PictBridge - Movie ) Price Comparison .
# Canon (- ) Price , , , Delhi, Chennai, Mumbai, , Kolkatta
# Canon Megapixel - - - (" - . Optical - Image - Video - - PictBridge - Movie ) Price Comparison .
# Canon + - - /.-. - s - Photo - Visual .
# Canon Megapixel - - - (" - . Optical - Image - Video - - PictBridge - Movie ) Price Comparison .
# Canon digital camera prices, Shopping comparison Canon , online - ShopMania
# Canon Megapixel - - - (" - . Optical - Image - Video - - PictBridge - Movie ) Price Comparison .
# Canon / - ( , . , CompactFlash ) Price Comparison .
# Canon Megapixel - - - (" - . Optical - Image - Video - - PictBridge - Movie ) Price Comparison .
# Canon / -105mm - Price comparison & reviews - s - Australia
# Canon Megapixel - - - (" - . Optical - Image - Video - - PictBridge - Movie ) Price Comparison .
# Canon 013803117493
# Canon 013803129052
# Canon 013803117493
# CamMarkt Canon .-
# Canon 013803117493
# Canon - Walmart.
# Canon 013803117493
# Canon - Walmart.
# Canon 013803117493
# Excellent Canon Japan 46646 013803129052
# Canon 013803117493
#  Canon Value
# Canon 013803117493
# Canon 013803129113
# Canon 013803117493
# Canon 013803129052
# Canon 013803117493
# Canon 013803129113
# Canon 013803117493
# Canon Tokina Reduce 013803129052
# Canon 013803117493
# Canon
# Canon 013803117493
#  Canon 013803129052
# Canon 013803117493
# Canon
# Canon 013803117493
# Canon 013803129052
# Canon 013803117493
#  Canon 013803129052
# Canon 013803117493
# Canon
# Canon 013803117493
# Canon - -
# Canon 013803117493
# Canon + -/.-. Zealand Prices - PriceMe
# Canon 013803117493
# Canon 013803129113
# Canon 013803117493
# Canon 013803129052
# Canon 013803117493
#  Canon , - s - - 4460B003 today Connection
# Canon 013803117493
# Nikon D3100 609728170875
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100 Tokyo Japan 018208919543
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100 Battery Filters
# Nikon D3200
# Nikon D3100 Nikon Refurbished
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100 25472
# Nikon D3200
# Nikon D3100 Nikkor
# Nikon D3200
# Nikon D3100 $.
# Nikon D3200
# Nikon D3100 Bundle
# Nikon D3200
#  Nikon D3100 Nikon Value Bundle
# Nikon D3200
# Nikon D3100 018208919543
# Nikon D3200
# Nikon D3100 018208254866
# Nikon D3200
# Nikon D3100 Snikkor
# Nikon D3200
# Nikon D3100 105mm
# Nikon D3200
# Nikon D3100 Tamron 300LD
# Nikon D3200
# Nikon D3100 Battery Charger 018208919543
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100 EXTRAS Bundle
# Nikon D3200
# Nikon D3100 018208254866
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100 Refurbished 25486 018208254866
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon Nikon Nikkor Sigma 300mm
# Nikon D3200
# Nikon D3100 17546 12384 018208919543
# Nikon D3200
# Nikon D3100 15556
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100 Double Nikkor Lenses 200mm 018208132843
# Nikon D3200
# Nikon D3100 Accessories 018208919543
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100 Battery Charger Bundle
# Nikon D3200
# Nikon D3100 Nikon Bundle 018208132843
# Nikon D3200
# Nikon D3100 Lenses
# Nikon D3200
#  Nikon D3100 Japan
# Nikon D3200
# Nikon D3100 Items Shown 018208919543
# Nikon D3200
# Nikon D3100 300mm
# Nikon D3200
# Nikon D3100 Nikon Refurbished
# Nikon D3200
# Nikon D3100 200mm
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100 200mm Carry
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100 Filter
# Nikon D3200
# Nikon D3100 300mm Lenses
# Nikon D3200
# Nikon D3100 300mm Lenses 18322
# Nikon D3200
# Nikon D3100 . $.
# Nikon D3200
# Nikon D3100 Battery Filters
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100 .-Megapixel Reviews Buzzillions.
# Nikon D3200
# Nikon D3100 018208919543
# Nikon D3200
# Nikon D3100 1080p 018208919543
# Nikon D3200
# Nikon D3100 Complete 018208919543
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Please First Nikon D3100 Nothing 018208919543
# Nikon D3200
# Nikon D3100 Certified
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100 . $.
# Nikon D3200
# Nikon D3100 Lenses Refurbished Nikon 13284B 018208132843
# Nikon D3200
# Nikon D3100 Nikon Certified 018208919543
# Nikon D3200
#  Nikon D3100 Package Lenses
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100 018208919543
# Nikon D3200
# Nikon D3100 Format 200mm Lenses Refur 018208132843
# Nikon D3200
# Nikon D3100 200mm Tamron
# Nikon D3200
# Nikon D3100 Tripod
# Nikon D3200
# Nikon D3100 Bookbag
# Nikon D3200
# Nikon D3100 15536
# Nikon D3200
# Nikon D3100 018208919543
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100 1080p Pentamirror
# Nikon D3200
# Nikon D3100 Excellent Japan
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100 018208919543
# Nikon D3200
# Nikon D3100 200mm Opened Unused 018208132843
# Nikon D3200
# Nikon D3100 Double 018208132843
# Nikon D3200
# Nikon D3100 300mm Lenses
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100 Battery Filters
# Nikon D3200
# Nikon D3100 Battery Charger
# Nikon D3200
# Nikon D3100 -
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100 200mm
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100 200mm
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100 018208919543
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100 Bundle 018208919543
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100 200mm Nikon Lenses
# Nikon D3200
# Nikon D3100 018208254866
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100 4026814 Clicks 018208919543
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon Series D3100 018208132843
# Nikon D3200
# Nikon D3100 200mm Extra
# Nikon D3200
# Nikon D3100 018208919543
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100 Lenses Description 018208132843
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100
# Nikon D3200
# Nikon D3100
# Nikon D3200
# 0.45255474452554745
# {'<page title>': 'Nikon D3200 DSLR Camera Body w Battery Pack and Charger | eBay', 'brand': 'Nikon', 'condition': 'Used: An item that has been used previously. The item may have some signs of cosmetic wear, but is fully\noperational and functions as intended. This item may be a floor model or store return that has been used. See the sellerâ\x80\x99s listing for full details and description of any imperfections.\nSee all condition definitions- opens in a new window or tab\n... Read moreabout the condition', 'kehs 180 day warranty': 'and 14 Day No Hassle Return\nPeriod', 'megapixels': '24.2', 'model': 'D3200', 'screen size': '3.0"'}
# {'<page title>': 'Canon EOS 7D 18 0 MP Digital SLR Camera with EF s 18 135mm F 3 5 5 6 Lens 013803117493 | eBay', 'brand': 'Canon', 'bundled items': 'Extra Battery, Extra Battery Charger, Lens, Strap (Neck or Wrist)', 'condition': 'Used: An item that has been used previously. The item may have some signs of cosmetic wear, but is fully\noperational and functions as intended. This item may be a floor model or store return that has been used. See the sellerâ\x80\x99s listing for full details and description of any imperfections.\nSee all condition definitions- opens in a new window or tab\n... Read moreabout the condition', 'manufacturer warranty': 'No', 'megapixels': '18.0 MP', 'model': '7D', 'mpn': '3814B004', 'optical zoom': '2.7x', 'screen size': '3"', 'type': 'Digital SLR', 'upc': '013803117493'}
# {'<page title>': 'Canon EOS 60D 18 Megapixel Digital SLR Camera Body With Lens Kit - 18 Mm - 55 Mm - Black (3" LCD - 3.1x Optical Zoom - 4272 X 2848 Image - 1920 X 1080 Video - HDMI - PictBridge - HD Movie Mode) Price Comparison at Buy.net', 'autofocus points': '9', 'battery builtin': 'No', 'battery include': 'Yes', 'battery model supported': 'LP-E6', 'battery rechargeable': 'Yes', 'brand name': 'Canon', 'builtin flash': 'Yes', 'camera body only': 'Body with Lens Kit', 'camera modes': 'Shooting Modes:StandardPortraitLandscapeNeutralFaithfulMonochromeUser Def. 1-3', 'camera type': 'Digital SLR Camera', 'depth': '3.1 in', 'digital zoom': 'No', 'effective megapixels': '18 Megapixel', 'exposure control': 'Program AEAperture PriorityShutter PriorityManual', 'flash': 'Auto Flash|Flash ON|Flash OFF|Red-eye Reduction', 'focal length': '18 mm to 55 mm (Lens 1)', 'gps': 'No', 'hd movie mode': 'Yes', 'height': '4.2 in', 'image sensor': 'CMOS', 'image stabilization': 'No', 'iso sensitivity': 'ISO 6400', 'language support': 'Japanese', 'lcd screen size': '3 in', 'lens construction': '11 Elements in 9 Groups', 'lens mount': 'Canon EF/EF-S', 'longest shutter speed': '60 Second', 'maximum diopter adjustment': '1', 'maximum frame rate': '30 fps', 'maximum video capture resolution': '1920 x 1080', 'memory card support': 'Secure Digital (SD) Card|Secure Digital Extended Capacity (SDXC)|Secure Digital High Capacity (SDHC) Card|Eye-Fi Card', 'minimum diopter adjustment': '-3', 'normalizedheight': '106.68', 'normalizedoptical zoom': '3.1', 'normalizedweight': '23.84', 'number of batteries support': '1', 'optical zoom': '3.1 X', 'pictbridge': 'Yes', 'product line': 'EOS', 'product model': '60D', 'shortest shutter speed': '1/8000 Second', 'total pixels': '19000000', 'url': 'http://www.usa.canon.com', 'viewfinder type': 'SLR', 'weight': '1.49 lbs', 'white balance modes': 'AutoDaylightShadeCloudyTungsten LightWhite Fluorescent LightFlashCustomColor Temperature Setting', 'width': '5.7 in'}
# {'<page title>': 'Nikon D3100 (18-55 mm & 55-200 mm) Price In India, Bangalore, Hyderabad, Delhi, Chennai, Mumbai, Pune, Kolkatta', 'aperture range': 'F3.5 (W) - F5.6 (T)', 'auto focus': 'Yes, Contrast Detect, Phase Detect, Multi-Area, Selective Single Point, Tracking, Single, Continuous, Face Detection, Live View', 'built in flash': 'Yes, Pop-Up', 'camera resolution': '15 MP', 'conitnous shots': 'Yes, 3 fps', 'delete function': 'Yes', 'external flash': 'Yes, Hot-shoe, Wireless plus sync connector', 'face detection': 'Yes', 'flash modes': 'Front Curtain Sync, Red Eye Reduction, Slow Sync with red eye reduction, Slow sync, rear curtain sync', 'flash range': '12.0 m', 'focal length': '18 - 55 mm (35 mm Equivalent to 27 - 82.5 mm)', 'image format': 'JPEG ( Fine, Normal & Basic Quality )', 'image stablizer': 'No', 'iso rating': '100 - 12800', 'lens type': 'Nikon F', 'manual focus': 'Yes', 'max resolution': '4608 x 3072 Pixels', 'maximum shutter speed': '1/4000 sec', 'metering': 'Yes, Multi-Pattern, Center-Weighted, Spot', 'minimum shutter speed': '30 Sec', 'other focus features': 'Focal Length Multiplier (1.5x), No. Of Focus Points (11)', 'processor': 'Expeed 2 Image Processing Engine', 'self timer': 'Yes, 2 or 10 sec', 'sensor size': 'APS-C (23.1 x 15.4 mm)', 'sensor type': 'CMOS', 'shooting modes': 'Single, Continuous @ 3 fps, Self Timer Mode, Quiet Shutter Release', 'supported languages': '20', 'sync terminal': 'Yes, 1/200 sec', 'video format': 'MPEG-4', 'white balancing': 'White Balance Presets (12), Custom White Balance (1), Incandescent, Fluorescent, Direct sunlight, Flash, Cloudy, Shade, White balance preset'}

# %%
rec_to_clust[centers[0]+'"']
# Out:
# '"ENTITY#44'

# %%
rec_to_clust[centers[1]+'"']
# Out:
# '"ENTITY#23'

# %%
rec_to_clust[centers[2]+'"']
# Out:
# '"ENTITY#36'

# %%
rec_to_clust[centers[3]+'"']
# Out:
# '"ENTITY#18'
